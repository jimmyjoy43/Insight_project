# %%
import boto3

client = boto3.client('s3') #low-level functional API

resource = boto3.resource('s3') #high-level object-oriented API
my_bucket = resource.Bucket('sagemaker-inspo') #subsitute this for your s3 bucket name.

# %%
import pandas as pd

obj = client.get_object(Bucket='sagemaker-inspo', Key='file_name.csv')
grid_sizes = pd.read_csv(obj['Body'])

# %%
grid_sizes
# Out:
#     0.6095173       0.0  1.2694421  0.07775737  0.16747868     0.0.1    0.0.2  \
# 0    0.113364  0.988888   1.437143    0.306887    0.000000  0.000000  0.00000
# 1    0.000000  0.000000   1.056550    0.000000    0.000000  0.204264  0.00000
# 2    0.577228  0.000000   0.695660    0.000000    0.940844  0.000000  0.00000
# 3    0.313765  0.157664   1.610840    0.638146    0.000000  0.000000  0.00000
# 4    0.169025  0.000000   0.433599    0.000000    0.222119  0.000000  0.00000
# 5    0.506961  0.000000   1.172692    0.084897    0.289463  0.000000  0.00000
# 6    0.000000  0.018187   0.848345    0.000000    0.000000  0.000000  0.00000
# 7    0.000000  0.266494   2.228413    0.682443    0.000000  0.000000  0.00000
# 8    0.480489  0.000000   1.260307    0.235430    0.000000  0.000000  0.00000
# 9    0.875628  0.000000   0.942665    0.000000    0.396765  0.000000  0.00000
# 10   0.000000  0.262497   0.624728    0.592221    0.000000  0.000000  0.00000
# ...
