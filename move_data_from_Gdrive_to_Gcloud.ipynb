# %% [markdown]
# <a href="https://colab.research.google.com/github/jimmy-io/Insight_project/blob/master/move_data_from_Gdrive_to_Gcloud.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
from google.colab import auth
auth.authenticate_user()
project_id = 'insight-265816'
# !gcloud config set project {project_id}
# !gsutil ls
# Out:
# Updated property [core/project].
#
#
# To take a quick anonymous survey, run:
#   $ gcloud survey
#
# gs://fbeans/
# gs://insight-265816.appspot.com/
# gs://staging.insight-265816.appspot.com/

# %%
bucket_name = 'fbeans'

# !gsutil -m cp -r /content/drive/My\ Drive/Insight/Project/fashionbeans gs://{bucket_name}/
# Out:
# Copying file:///content/drive/My Drive/Insight/Project/fashionbeans/processed/421286.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/My Drive/Insight/Project/fashionbeans/processed/421282.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/My Drive/Insight/Project/fashionbeans/processed/421289.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/My Drive/Insight/Project/fashionbeans/processed/421290.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/My Drive/Insight/Project/fashionbeans/processed/421287.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/My Drive/Insight/Project/fashionbeans/processed/421285.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/My Drive/Insight/Project/fashionbeans/processed/431294.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/My Drive/Insight/Project/fashionbeans/processed/421283.jpg [Content-Type=image/jpeg]...
# ...
